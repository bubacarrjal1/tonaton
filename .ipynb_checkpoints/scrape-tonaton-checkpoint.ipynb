# %%
import requests
from bs4 import BeautifulSoup
import time

# Make a GET request to fetch the raw HTML content
source = requests.get('https://tonaton.com/en/ads/ghana/land').text

# parse the html content
soup = BeautifulSoup(source, "lxml")
# print(soup.prettify())

for info in soup.find_all('div', class_="container--2uFyv"):
    title = info.find('span', class_="title--3yncE").text
    print(title)

    size = info.find('div', class_="content--3JNQz").div.div.text
    print(size)

    region = info.find('div', class_="description--2-ez3").text
    print(region)

    price = info.find('div', class_="price--3SnqI color--t0tGX").span.text
    print(price)
    
    print()
# Out:
# Litigation Free Land @ Dodowa Ayikuma for sale
# 70/100 sqft
# Greater Accra, Land
# GHâµ 12,000
#
# âï¸ AFIENYA - LANDS FOR SALE ___ (REGISTERED REAL ESTATE PLOTS)
# 70X100 sqft
# Greater Accra, Land
# GHâµ 35,000
#
# Registered one Acre plot of land for sale @ East legon west trassaco
# 200/140 sqft
# Accra, Land
# GHâµ 15,000,000
#
# FULLY DEMARCATED LANDS AT TSOPOLI AIRPORT CITY ON SALE...
# 70.100 sqft
# Accra, Land
# GHâµ 13,000
#
# One and half plot at Dziayor (Adjiringanor)
# 100 x 95 sqft
# Accra, Land
# GHâµ 260,000
#
# TSOPOLI RESIDENTIAL SECURED - PLOTS OF LAND 4SALE
# 50/70 sqft
# Greater Accra, Land
# GHâµ 5,000
#
# (GENUINE REGISTERED) LANDS IN TSOPOLI 4SALE
# 50/70 sqft
# Greater Accra, Land
# GHâµ 5,000
#
# plot of Land at patase
# 125*110 sqft
# Kumasi, Land
# GHâµ 550,000
#
# GENUINE (TSOPOLI DEVELOPED ESTATE COMMUNITY) LANDS FOR SALE !!!
# 50/70 sqft
# Greater Accra, Land
# GHâµ 5,000
#
# [TSOPOLI] LANDS FOR SALE __ (NO LAND GUARDS) _______
# 50/70 sqft
# Greater Accra, Land
# GHâµ 5,000
#
# {TSOPOLI LANDS} - (70X50) _ (AFFORDABLE LANDS)
# 50/70 sqft
# Greater Accra, Land
# GHâµ 5,000
#
# title estate lands@ new airport residential.
# 100/70 sqft
# Greater Accra, Land
# GHâµ 11,000
#
# TSOPOLI PLOTS_VERY AFFORDABLE SALES
# 100/70 sqft
# Greater Accra, Land
# GHâµ 13,000
#
# LARGE TSOPOLI AIRPORT CITY LANDS ON SALE NEAR PRAMPRAM
# 70.100 sqft
# Accra, Land
# GHâµ 13,000
#
# COOL PRICE REDUCTION ON GATED COMMUNITY LANDS@TEMA C25
# 70/100 sqft
# Greater Accra, Land
# GHâµ 35,000
#
# MODERATE PRICE ON PRAMPRAM BEACH LANE PLOTS.
# 70/100 sqft
# Greater Accra, Land
# GHâµ 18,000
#
# IDEAL OYIBI-APPOLONIA GATED COMMUNITY LAND.
# 70/100 sqft
# Greater Accra, Land
# GHâµ 55,000
#
# GET YOUR PLOTTED LANDS @ TSOPOLI
# 70x100 sqft
# Greater Accra, Land
# GHâµ 16,000
#
# No Litigation Estate Plots Prampram
# 70/50 sqft
# Greater Accra, Land
# GHâµ 5,500
#
# PRAMPRAM BEACH LANE BIG PROMO ON GATED COMMUNITY PLOTS.
# 70/100 sqft
# Greater Accra, Land
# GHâµ 18,000
#
# SUPER PROMO SALES OF PLOTS @ TSOPOLI
# 70x100 sqft
# Greater Accra, Land
# GHâµ 16,000
#
# Genuine Titled Plots 4 Sale@ East Legon Hills.
# 70 sqft
# Accra, Land
# GHâµ 120,000
#
# AFFORDABLE ACRES OF LAND FOR SALE@ PRAMPRAM BEACH ROAD
# 70 X 100 sqft
# Greater Accra, Land
# GHâµ 18,000
#
# Registered 11 plot Abokobi
# 100/70 sqft
# Accra, Land
# GHâµ 495,000
#
# Registered 4 acres plot Abokobi
# 100/70 sqft
# Accra, Land
# GHâµ 720,000
#
# residential plot for sale at Kansa city
# 100x100 sqft
# Sekondi Takoradi, Land
# GHâµ 27,000
#
# residential plot for sale at Effia mapees
# 100x60 sqft
# Sekondi Takoradi, Land
# GHâµ 40,000
